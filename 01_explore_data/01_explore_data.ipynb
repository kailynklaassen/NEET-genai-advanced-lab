# %% [markdown]
# ## Data Exploration
#
# Let's explore the data before jumping into transformation. Understanding the structure and content will help guide the preprocessing steps.

# %%
# %run ../00_setup/config

# %%
spark.sql(f"USE CATALOG `{catalog_name}`")
spark.sql(f"USE SCHEMA  `{schema_name}`")

# %%
# %sql
SELECT current_catalog(), current_schema()

# %%
# %sql
-- we will use this table to create vector search indexes
SELECT * FROM databricks_workshop.jywu.product_docs
LIMIT 5

# %%
# %sql
-- we will use this table create SQL functions
SELECT * FROM databricks_workshop.jywu.customer_services
LIMIT 5

# %%
# %sql
-- we will use this table create SQL functions
SELECT * FROM databricks_workshop.jywu.policies
LIMIT 5
