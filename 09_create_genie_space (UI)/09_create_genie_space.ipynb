# %% [markdown]
# # Add AI-generate descriptions and comments

# %% [markdown]
# ![Image Description](./ai_generated_comments.png)

# %% [markdown]
# # Set up Genie Space in UI

# %% [markdown]
# ![Image Description](./genie_space.png)
